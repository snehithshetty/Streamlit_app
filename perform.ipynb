# %%
# %config Completer.use_jedi = False
from snowflake.snowpark.session import Session
from snowflake.snowpark import DataFrame, Window
from snowflake.snowpark.types import *
from snowflake.snowpark import functions as F
from snowflake.snowpark.functions import col, lit

# Snowflake connection info is saved in config.py
from config import snowflake_conn_prop

# %%
session = Session.builder.configs(snowflake_conn_prop).create()
session.sql("use role {}".format(snowflake_conn_prop['role'])).collect()
session.sql("use database {}".format(snowflake_conn_prop['database'])).collect()
session.sql("use schema {}".format(snowflake_conn_prop['schema'])).collect()
session.sql("use warehouse {}".format(snowflake_conn_prop['warehouse']))
print(session.sql('select current_warehouse(), current_database(), current_schema(), current_user()').collect())

# %%
df = session.table("RETAIL")
df.show()
# Out:
# -------------------------------------------------------------------------------------------------------------------
# |"INVOICENO"  |"STOCKCODE"  |"DESCRIPTION"  |"QUANTITY"  |"INVOICEDATE"  |"UNITPRICE"  |"CUSTOMERID"  |"COUNTRY"  |
# -------------------------------------------------------------------------------------------------------------------
# |             |             |               |            |               |             |              |           |
# -------------------------------------------------------------------------------------------------------------------

# %%
df.describe().show()
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------------
# |"SUMMARY"  |"INVOICENO"  |"STOCKCODE"  |"DESCRIPTION"                   |"QUANTITY"  |"UNITPRICE"        |"CUSTOMERID"       |"COUNTRY"    |
# ---------------------------------------------------------------------------------------------------------------------------------------------
# |count      |541909       |541909       |540455                          |541909      |541909.0           |406829.0           |541909       |
# |mean       |NULL         |NULL         |NULL                            |NULL        |4.61111362         |15287.69057        |NULL         |
# |stddev     |NULL         |NULL         |NULL                            |NULL        |96.75985306153116  |1713.600303321635  |NULL         |
# |min        |536365       |10002        | 4 PURPLE FLOCK DINNER CANDLES  |-1          |-11062.06          |12346.0            |Australia    |
# |max        |C581569      |m            |wrongly sold sets               |992         |38970.0            |18287.0            |Unspecified  |
# ---------------------------------------------------------------------------------------------------------------------------------------------

# %%
df = df.dropna()
df = df.filter("QUANTITY > 0 and UNITPRICE > 0")
df.show()
# Out:
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# |"INVOICENO"  |"STOCKCODE"  |"DESCRIPTION"                        |"QUANTITY"  |"INVOICEDATE"        |"UNITPRICE"  |"CUSTOMERID"  |"COUNTRY"       |
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# |536365       |85123A       |WHITE HANGING HEART T-LIGHT HOLDER   |6           |2010-12-01 08:26:00  |2.55         |17850         |United Kingdom  |
# |536365       |71053        |WHITE METAL LANTERN                  |6           |2010-12-01 08:26:00  |3.39         |17850         |United Kingdom  |
# |536365       |84406B       |CREAM CUPID HEARTS COAT HANGER       |8           |2010-12-01 08:26:00  |2.75         |17850         |United Kingdom  |
# |536365       |84029G       |KNITTED UNION FLAG HOT WATER BOTTLE  |6           |2010-12-01 08:26:00  |3.39         |17850         |United Kingdom  |
# |536365       |84029E       |RED WOOLLY HOTTIE WHITE HEART.       |6           |2010-12-01 08:26:00  |3.39         |17850         |United Kingdom  |
# |536365       |22752        |SET 7 BABUSHKA NESTING BOXES         |2           |2010-12-01 08:26:00  |7.65         |17850         |United Kingdom  |
# |536365       |21730        |GLASS STAR FROSTED T-LIGHT HOLDER    |6           |2010-12-01 08:26:00  |4.25         |17850         |United Kingdom  |
# |536366       |22633        |HAND WARMER UNION JACK               |6           |2010-12-01 08:28:00  |1.85         |17850         |United Kingdom  |
# |536366       |22632        |HAND WARMER RED POLKA DOT            |6           |2010-12-01 08:28:00  |1.85         |17850         |United Kingdom  |
# |536367       |84879        |ASSORTED COLOUR BIRD ORNAMENT        |32          |2010-12-01 08:34:00  |1.69         |13047         |United Kingdom  |
# ----------------------------------------------------------------------------------------------------------------------------------------------------

# %%
df.group_by("COUNTRY").count().show()
# Out:
# ----------------------------
# |"COUNTRY"       |"COUNT"  |
# ----------------------------
# |United Kingdom  |495478   |
# |France          |8557     |
# |Australia       |1259     |
# |Netherlands     |2371     |
# |Germany         |9495     |
# |Norway          |1086     |
# |Switzerland     |2002     |
# |Spain           |2533     |
# |Poland          |341      |
# |Portugal        |1519     |
# ----------------------------

# %%
df = df.filter("COUNTRY = 'United Kingdom'")

# %%
df.show()
# Out:
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# |"INVOICENO"  |"STOCKCODE"  |"DESCRIPTION"                        |"QUANTITY"  |"INVOICEDATE"        |"UNITPRICE"  |"CUSTOMERID"  |"COUNTRY"       |
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# |536365       |85123A       |WHITE HANGING HEART T-LIGHT HOLDER   |6           |2010-12-01 08:26:00  |2.55         |17850         |United Kingdom  |
# |536365       |71053        |WHITE METAL LANTERN                  |6           |2010-12-01 08:26:00  |3.39         |17850         |United Kingdom  |
# |536365       |84406B       |CREAM CUPID HEARTS COAT HANGER       |8           |2010-12-01 08:26:00  |2.75         |17850         |United Kingdom  |
# |536365       |84029G       |KNITTED UNION FLAG HOT WATER BOTTLE  |6           |2010-12-01 08:26:00  |3.39         |17850         |United Kingdom  |
# |536365       |84029E       |RED WOOLLY HOTTIE WHITE HEART.       |6           |2010-12-01 08:26:00  |3.39         |17850         |United Kingdom  |
# |536365       |22752        |SET 7 BABUSHKA NESTING BOXES         |2           |2010-12-01 08:26:00  |7.65         |17850         |United Kingdom  |
# |536365       |21730        |GLASS STAR FROSTED T-LIGHT HOLDER    |6           |2010-12-01 08:26:00  |4.25         |17850         |United Kingdom  |
# |536366       |22633        |HAND WARMER UNION JACK               |6           |2010-12-01 08:28:00  |1.85         |17850         |United Kingdom  |
# |536366       |22632        |HAND WARMER RED POLKA DOT            |6           |2010-12-01 08:28:00  |1.85         |17850         |United Kingdom  |
# |536367       |84879        |ASSORTED COLOUR BIRD ORNAMENT        |32          |2010-12-01 08:34:00  |1.69         |13047         |United Kingdom  |
# ----------------------------------------------------------------------------------------------------------------------------------------------------

# %%
df = df.join(df.select(F.max("INVOICEDATE").alias("NOW")))

#RECENCY, FREQUENCY, MONETARY
df_tf = df.group_by("CUSTOMERID")\
          .agg(F.max("INVOICEDATE"),\
               F.max("NOW"),\
               F.sum(col("QUANTITY")*col("UNITPRICE")).alias("Monetary"),\
               F.count("INVOICENO").alias("Frequency")).select("CUSTOMERID","Frequency","Monetary",\
                                    F.datediff("days",col("MAX(INVOICEDATE)"),col("MAX(NOW)")).alias("RECENCY"))

df_tf.show()
# Out:
# ----------------------------------------------------------
# |"CUSTOMERID"  |"FREQUENCY"  |"MONETARY"     |"RECENCY"  |
# ----------------------------------------------------------
# |17850         |312          |5288.6300000   |302        |
# |13047         |196          |3079.1000000   |31         |
# |13748         |28           |948.2500000    |95         |
# |15100         |6            |635.1000000    |330        |
# |15291         |109          |4596.5100000   |25         |
# |17809         |64           |4627.6200000   |16         |
# |16098         |67           |2005.6300000   |87         |
# |18074         |13           |489.6000000    |373        |
# |17420         |30           |598.8300000    |50         |
# |17511         |1076         |88125.3800000  |2          |
# ----------------------------------------------------------

# %%
freq_99pc = df_tf.select(F.percentile_cont(0.99).within_group("FREQUENCY")).collect()
rec_99pc = df_tf.select(F.percentile_cont(0.99).within_group("RECENCY")).collect()
mon_99pc = df_tf.select(F.percentile_cont(0.99).within_group("MONETARY")).collect()

df_tf = df_tf.filter((col("FREQUENCY") < freq_99pc[0][0]) & \
                     (col("RECENCY") < rec_99pc[0][0]) & \
                     (col("MONETARY") < mon_99pc[0][0]))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(1, 3, figsize=(16, 8))

df_pd = df_tf.select("CUSTOMERID", "FREQUENCY", "RECENCY", "MONETARY").toPandas()

# Recency distribution plot
sns.histplot(df_pd['RECENCY'], kde=True, ax=ax[0])

# Frequency distribution plot
sns.histplot(df_pd['FREQUENCY'], kde=True, ax=ax[1])

# Monetary distribution plot
sns.histplot(df_pd['MONETARY'], kde=True, ax=ax[2])
# Out:
# <Axes: xlabel='MONETARY', ylabel='Count'>

# %%
# Implementation code for the stored procedure
def kmeans_cluster (session: Session, max_iter: int, iterate: int) -> str:
        
    import pandas as pd
    from sklearn.preprocessing import StandardScaler
    from sklearn.cluster import KMeans


    scaler = StandardScaler()
    scaler.fit(df_pd[["FREQUENCY", "RECENCY", "MONETARY"]])
    print(scaler.mean_)
    df_train = scaler.transform(df_pd[["FREQUENCY", "RECENCY", "MONETARY"]])
    print (df_train)
    inertia = []
    results = []
    
    #sdf = session.createDataFrame(pdf_rules)
    #sdf.write.saveAsTable(to_table,mode="overwrite")


    if iterate==1:
        K = range(2,max_iter)
        for k in K:
            model = KMeans(n_clusters=k, init='k-means++', random_state=42).fit(df_train)
            inertia.append(model.inertia_)
            results = inertia
    else:
        df_pd['Cluster'] = KMeans(n_clusters=max_iter, init='k-means++', random_state=42).fit(df_train).labels_
        df_output = session.createDataFrame(df_pd)
        df_output.write.saveAsTable("RFM_Clusters",mode="overwrite")
        results = "MODEL CREATED"
        
    return results

# %%
from snowflake.snowpark.functions import sproc

# This adds the necessary packages to our Python environment in Snowflake
# session.clear_packages()
session.add_packages("snowflake-snowpark-python","pandas","scikit-learn")

# We need a stage to host the stored proc
_ = session.sql('CREATE STAGE IF NOT EXISTS MODELS').collect()

# Register the stored proc
session.sproc.register(kmeans_cluster, name="kmeans_cluster", is_permanent=True, stage_location="@models", replace=True)
# Out:
# The version of package scikit-learn in the local environment is 1.2.1, which does not fit the criteria for the requirement scikit-learn. Your UDF might not work when the package version is different between the server and your local environment
# Failed to execute query [queryID: 01aaa668-3200-aac2-0000-0003728670ed]
# CREATE OR REPLACE
#   PROCEDURE kmeans_cluster(arg1 BIGINT,arg2 BIGINT)
# RETURNS STRING
# LANGUAGE PYTHON
# RUNTIME_VERSION=3.8
# IMPORTS=('@models/kmeans_cluster/udf_py_186876245.zip')
# PACKAGES=('snowflake-snowpark-python','pandas','scikit-learn','cloudpickle==2.0.0')
# HANDLER='udf_py_186876245.compute'
# EXECUTE AS OWNER
#
#
#
# 391529 (42501): SQL compilation error: Anaconda terms must be accepted by ORGADMIN to use Anaconda 3rd party packages. Please follow the instructions at https://docs.snowflake.com/en/developer-guide/udf/python/udf-python-packages.html#using-third-party-packages-from-anaconda.
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[27], line 11
#       8 _ = session.sql('CREATE STAGE IF NOT EXISTS MODELS').collect()
#      10 # Register the stored proc
# ---> 11 session.sproc.register(kmeans_cluster, name="kmeans_cluster", is_permanent=True, stage_location="@models", replace=True)
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\stored_procedure.py:420, in StoredProcedureRegistration.register(self, func, return_type, input_types, name, is_permanent, stage_location, imports, packages, replace, parallel, execute_as, strict, statement_params)
#     415 check_register_args(
#     416     TempObjectType.PROCEDURE, name, is_permanent, stage_location, parallel
#     417 )
#     419 # register stored procedure
# --> 420 return self._do_register_sp(
#     421     func,
#     422     return_type,
#     423     input_types,
#     424     name,
#     425     stage_location,
#     426     imports,
#     427     packages,
#     428     replace,
#     429     parallel,
#     430     strict,
#     431     statement_params=statement_params,
#     432     execute_as=execute_as,
#     433     api_call_source="StoredProcedureRegistration.register",
#     434 )
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\stored_procedure.py:630, in StoredProcedureRegistration._do_register_sp(self, func, return_type, input_types, sp_name, stage_location, imports, packages, replace, parallel, strict, statement_params, execute_as, api_call_source)
#     626     tb = sys.exc_info()[2]
#     627     ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     628         pe
#     629     )
# --> 630     raise ne.with_traceback(tb) from None
#     631 except BaseException:
#     632     raised = True
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\stored_procedure.py:604, in StoredProcedureRegistration._do_register_sp(self, func, return_type, input_types, sp_name, stage_location, imports, packages, replace, parallel, strict, statement_params, execute_as, api_call_source)
#     602 raised = False
#     603 try:
# --> 604     create_python_udf_or_sp(
#     605         session=self._session,
#     606         return_type=return_type,
#     607         input_args=input_args,
#     608         handler=handler,
#     609         object_type=TempObjectType.PROCEDURE,
#     610         object_name=udf_name,
#     611         all_imports=all_imports,
#     612         all_packages=all_packages,
#     613         is_temporary=stage_location is None,
#     614         replace=replace,
#     615         inline_python_code=code,
#     616         execute_as=execute_as,
#     617         api_call_source=api_call_source,
#     618         strict=strict,
#     619     )
#     620 # an exception might happen during registering a stored procedure
#     621 # (e.g., a dependency might not be found on the stage),
#     622 # then for a permanent stored procedure, we should delete the uploaded
#     623 # python file and raise the exception
#     624 except ProgrammingError as pe:
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\_internal\udf_utils.py:690, in create_python_udf_or_sp(session, return_type, input_args, handler, object_type, object_name, all_imports, all_packages, is_temporary, replace, inline_python_code, execute_as, api_call_source, strict, secure)
#     677     strict_as_sql = "\nSTRICT" if strict else ""
#     679     create_query = f"""
#     680 CREATE{" OR REPLACE " if replace else ""}
#     681 {"TEMPORARY" if is_temporary else ""} {"SECURE" if secure else ""} {object_type.value} {object_name}({sql_func_args})
#    (...)
#     688 {inline_python_code_in_sql}
#     689 """
# --> 690     session._run_query(create_query, is_ddl_on_temp_object=is_temporary)
#     692     # fire telemetry after _run_query is successful
#     693     api_call_source = api_call_source or "_internal.create_python_udf_or_sp"
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\session.py:1139, in Session._run_query(self, query, is_ddl_on_temp_object)
#    1138 def _run_query(self, query: str, is_ddl_on_temp_object: bool = False) -> List[Any]:
# -> 1139     return self._conn.run_query(query, is_ddl_on_temp_object=is_ddl_on_temp_object)[
#    1140         "data"
#    1141     ]
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:104, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     100     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     101         ex.cause
#     102     )
#     103 except Exception as ex:
# --> 104     raise ex
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:98, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#      96     raise SnowparkClientExceptionMessages.SERVER_SESSION_HAS_BEEN_CLOSED()
#      97 try:
# ---> 98     return func(*args, **kwargs)
#      99 except ReauthenticationRequest as ex:
#     100     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     101         ex.cause
#     102     )
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:333, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, **kwargs)
#     331     query_id_log = f" [queryID: {ex.sfqid}]" if hasattr(ex, "sfqid") else ""
#     332     logger.error(f"Failed to execute query{query_id_log} {query}\n{ex}")
# --> 333     raise ex
#     335 # fetch_pandas_all/batches() only works for SELECT statements
#     336 # We call fetchall() if fetch_pandas_all/batches() fails,
#     337 # because when the query plan has multiple queries, it will
#     338 # have non-select statements, and it shouldn't fail if the user
#     339 # calls to_pandas() to execute the query.
#     340 if block:
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:317, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, **kwargs)
#     315     kwargs["_statement_params"]["SNOWPARK_SKIP_TXN_COMMIT_IN_DDL"] = True
#     316 if block:
# --> 317     results_cursor = self._cursor.execute(query, **kwargs)
#     318     self.notify_query_listeners(
#     319         QueryRecord(results_cursor.sfqid, results_cursor.query)
#     320     )
#     321     logger.debug(f"Execute query [queryID: {results_cursor.sfqid}] {query}")
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\connector\cursor.py:804, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, file_stream)
#     800     is_integrity_error = (
#     801         code == "100072"
#     802     )  # NULL result in a non-nullable column
#     803     error_class = IntegrityError if is_integrity_error else ProgrammingError
# --> 804     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#     805 return self
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\connector\errors.py:276, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     253 @staticmethod
#     254 def errorhandler_wrapper(
#     255     connection: SnowflakeConnection | None,
#    (...)
#     258     error_value: dict[str, str | bool | int],
#     259 ) -> None:
#     260     """Error handler wrapper that calls the errorhandler method.
#     261
#     262     Args:
#    (...)
#     273         exception to the first handler in that order.
#     274     """
# --> 276     handed_over = Error.hand_to_other_handler(
#     277         connection,
#     278         cursor,
#     279         error_class,
#     280         error_value,
#     281     )
#     282     if not handed_over:
#     283         raise Error.errorhandler_make_exception(
#     284             error_class,
#     285             error_value,
#     286         )
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\connector\errors.py:331, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     329 if cursor is not None:
#     330     cursor.messages.append((error_class, error_value))
# --> 331     cursor.errorhandler(connection, cursor, error_class, error_value)
#     332     return True
#     333 elif connection is not None:
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\connector\errors.py:210, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     192 @staticmethod
#     193 def default_errorhandler(
#     194     connection: SnowflakeConnection,
#    (...)
#     197     error_value: dict[str, str],
#     198 ) -> None:
#     199     """Default error handler that raises an error.
#     200
#     201     Args:
#    (...)
#     208         A Snowflake error.
#     209     """
# --> 210     raise error_class(
#     211         msg=error_value.get("msg"),
#     212         errno=error_value.get("errno"),
#     213         sqlstate=error_value.get("sqlstate"),
#     214         sfqid=error_value.get("sfqid"),
#     215         done_format_msg=error_value.get("done_format_msg"),
#     216         connection=connection,
#     217         cursor=cursor,
#     218     )
#
# SnowparkSQLException: (1304): 01aaa668-3200-aac2-0000-0003728670ed: 391529 (42501): SQL compilation error: Anaconda terms must be accepted by ORGADMIN to use Anaconda 3rd party packages. Please follow the instructions at https://docs.snowflake.com/en/developer-guide/udf/python/udf-python-packages.html#using-third-party-packages-from-anaconda.

# %%
max_iter = 12
results = session.call("kmeans_cluster", max_iter, 1)
inertia = np.array(results[1:-1].split(',')).astype(float)
# Out:
# Failed to execute query [queryID: 01aaa662-3200-aac6-0000-00037286907d] CALL kmeans_cluster(12 :: INT, 1 :: INT)
# 002140 (42601): SQL compilation error:
# Unknown function KMEANS_CLUSTER
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[14], line 2
#       1 max_iter = 12
# ----> 2 results = session.call("kmeans_cluster", max_iter, 1)
#       3 inertia = np.array(results[1:-1].split(',')).astype(float)
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\session.py:1805, in Session.call(self, sproc_name, *args)
#    1803 df = self.sql(f"CALL {sproc_name}({', '.join(sql_args)})")
#    1804 set_api_call_source(df, "Session.call")
# -> 1805 return df.collect()[0][0]
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\_internal\telemetry.py:138, in df_collect_api_telemetry.<locals>.wrap(*args, **kwargs)
#     135 @functools.wraps(func)
#     136 def wrap(*args, **kwargs):
#     137     with args[0]._session.query_history() as query_history:
# --> 138         result = func(*args, **kwargs)
#     139     plan = args[0]._select_statement or args[0]._plan
#     140     api_calls = [
#     141         *plan.api_calls,
#     142         {TelemetryField.NAME.value: f"DataFrame.{func.__name__}"},
#     143     ]
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\dataframe.py:546, in DataFrame.collect(self, statement_params, block)
#     530 @df_collect_api_telemetry
#     531 def collect(
#     532     self, *, statement_params: Optional[Dict[str, str]] = None, block: bool = True
#     533 ) -> Union[List[Row], AsyncJob]:
#     534     """Executes the query representing this DataFrame and returns the result as a
#     535     list of :class:`Row` objects.
#     536
#    (...)
#     544         :meth:`collect_nowait()`
#     545     """
# --> 546     return self._internal_collect_with_tag_no_telemetry(
#     547         statement_params=statement_params, block=block
#     548     )
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\dataframe.py:581, in DataFrame._internal_collect_with_tag_no_telemetry(self, statement_params, block, data_type)
#     571 def _internal_collect_with_tag_no_telemetry(
#     572     self,
#     573     *,
#    (...)
#     579     # we should always call this method instead of collect(), to make sure the
#     580     # query tag is set properly.
# --> 581     return self._session._conn.execute(
#     582         self._plan,
#     583         block=block,
#     584         data_type=data_type,
#     585         _statement_params=create_or_update_statement_params_with_query_tag(
#     586             statement_params, self._session.query_tag, SKIP_LEVELS_THREE
#     587         ),
#     588     )
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:406, in ServerConnection.execute(self, plan, to_pandas, to_iter, block, data_type, **kwargs)
#     402 if is_in_stored_procedure() and not block:  # pragma: no cover
#     403     raise NotImplementedError(
#     404         "Async query is not supported in stored procedure yet"
#     405     )
# --> 406 result_set, result_meta = self.get_result_set(
#     407     plan, to_pandas, to_iter, **kwargs, block=block, data_type=data_type
#     408 )
#     409 if not block:
#     410     return result_set
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\_internal\analyzer\snowflake_plan.py:156, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     152 else:
#     153     ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     154         e
#     155     )
# --> 156     raise ne.with_traceback(tb) from None
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\_internal\analyzer\snowflake_plan.py:89, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#      87 def wrap(*args, **kwargs):
#      88     try:
# ---> 89         return func(*args, **kwargs)
#      90     except snowflake.connector.errors.ProgrammingError as e:
#      91         tb = sys.exc_info()[2]
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:494, in ServerConnection.get_result_set(self, plan, to_pandas, to_iter, block, data_type, **kwargs)
#     492 for holder, id_ in placeholders.items():
#     493     final_query = final_query.replace(holder, id_)
# --> 494 result = self.run_query(
#     495     final_query,
#     496     to_pandas,
#     497     to_iter and (i == len(plan.queries) - 1),
#     498     is_ddl_on_temp_object=query.is_ddl_on_temp_object,
#     499     block=not is_last,
#     500     data_type=data_type,
#     501     async_job_plan=plan,
#     502     **kwargs,
#     503 )
#     504 placeholders[query.query_id_place_holder] = (
#     505     result["sfqid"] if not is_last else result.query_id
#     506 )
#     507 result_meta = self._cursor.description
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:104, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     100     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     101         ex.cause
#     102     )
#     103 except Exception as ex:
# --> 104     raise ex
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:98, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#      96     raise SnowparkClientExceptionMessages.SERVER_SESSION_HAS_BEEN_CLOSED()
#      97 try:
# ---> 98     return func(*args, **kwargs)
#      99 except ReauthenticationRequest as ex:
#     100     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     101         ex.cause
#     102     )
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:333, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, **kwargs)
#     331     query_id_log = f" [queryID: {ex.sfqid}]" if hasattr(ex, "sfqid") else ""
#     332     logger.error(f"Failed to execute query{query_id_log} {query}\n{ex}")
# --> 333     raise ex
#     335 # fetch_pandas_all/batches() only works for SELECT statements
#     336 # We call fetchall() if fetch_pandas_all/batches() fails,
#     337 # because when the query plan has multiple queries, it will
#     338 # have non-select statements, and it shouldn't fail if the user
#     339 # calls to_pandas() to execute the query.
#     340 if block:
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\snowpark\_internal\server_connection.py:317, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, **kwargs)
#     315     kwargs["_statement_params"]["SNOWPARK_SKIP_TXN_COMMIT_IN_DDL"] = True
#     316 if block:
# --> 317     results_cursor = self._cursor.execute(query, **kwargs)
#     318     self.notify_query_listeners(
#     319         QueryRecord(results_cursor.sfqid, results_cursor.query)
#     320     )
#     321     logger.debug(f"Execute query [queryID: {results_cursor.sfqid}] {query}")
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\connector\cursor.py:804, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, file_stream)
#     800     is_integrity_error = (
#     801         code == "100072"
#     802     )  # NULL result in a non-nullable column
#     803     error_class = IntegrityError if is_integrity_error else ProgrammingError
# --> 804     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#     805 return self
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\connector\errors.py:276, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     253 @staticmethod
#     254 def errorhandler_wrapper(
#     255     connection: SnowflakeConnection | None,
#    (...)
#     258     error_value: dict[str, str | bool | int],
#     259 ) -> None:
#     260     """Error handler wrapper that calls the errorhandler method.
#     261
#     262     Args:
#    (...)
#     273         exception to the first handler in that order.
#     274     """
# --> 276     handed_over = Error.hand_to_other_handler(
#     277         connection,
#     278         cursor,
#     279         error_class,
#     280         error_value,
#     281     )
#     282     if not handed_over:
#     283         raise Error.errorhandler_make_exception(
#     284             error_class,
#     285             error_value,
#     286         )
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\connector\errors.py:331, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     329 if cursor is not None:
#     330     cursor.messages.append((error_class, error_value))
# --> 331     cursor.errorhandler(connection, cursor, error_class, error_value)
#     332     return True
#     333 elif connection is not None:
#
# File ~\anaconda3\envs\Streamlit\lib\site-packages\snowflake\connector\errors.py:210, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     192 @staticmethod
#     193 def default_errorhandler(
#     194     connection: SnowflakeConnection,
#    (...)
#     197     error_value: dict[str, str],
#     198 ) -> None:
#     199     """Default error handler that raises an error.
#     200
#     201     Args:
#    (...)
#     208         A Snowflake error.
#     209     """
# --> 210     raise error_class(
#     211         msg=error_value.get("msg"),
#     212         errno=error_value.get("errno"),
#     213         sqlstate=error_value.get("sqlstate"),
#     214         sfqid=error_value.get("sfqid"),
#     215         done_format_msg=error_value.get("done_format_msg"),
#     216         connection=connection,
#     217         cursor=cursor,
#     218     )
#
# SnowparkSQLException: (1304): 01aaa662-3200-aac6-0000-00037286907d: 002140 (42601): SQL compilation error:
# Unknown function KMEANS_CLUSTER

# %%
import matplotlib.pyplot as plt

K = range(2,max_iter)
plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('Inertia')
plt.title('Elbow Chart')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       3 K = range(2,max_iter)
#       4 plt.figure(figsize=(16,8))
# ----> 5 plt.plot(K, inertia, 'bx-')
#       6 plt.xlabel('k')
#       7 plt.ylabel('Inertia')
#
# NameError: name 'inertia' is not defined

# %%
max_iter = 4
results = session.call("kmeans_cluster", max_iter, 0)
